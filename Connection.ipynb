# %% [markdown]
# Create a connection between csv file and newly create table/database in mysql workbench

# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
data=pd.read_csv(r'C:\Users\Amir\Dropbox\Workshop demo\Retail Project\SQL section\data.csv')

# %%
username='root'
password='root'
database='retail'
host='localhost'
port='127.0.0.1'

# %%
# Build a connection string
connection_string = f'mysql+pymysqlconnector://{username}:{password}@{host}:{port}/{database}'
print(connection_string)
# Out:
# mysql+pymysqlconnector://root:root@localhost:3306/retail

# %%
# Create engine variable
from sqlalchemy.engine import make_url, create_engine
import pymysql

engine = create_engine('mysql+pymysql://root:root@127.0.0.1/retail')

data.to_sql('retail', engine, index=False)
print("Success!")
# Out:
# Success!
